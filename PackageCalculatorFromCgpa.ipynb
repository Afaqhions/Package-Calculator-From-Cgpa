# %%
# Importing all packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

# %%
# Dataset
dataset = pd.read_csv(r"C:\Users\User\Desktop\Projects\Machine Learning\Dataset.csv")
dataset.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
# Validating dataset
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
# Plotting Graph 
sns.scatterplot(x='cgpa',y='package',data=dataset)
plt.title("Graph between Cgpa & Pakage")
plt.show()

# %%
# Splitting Train & Test Data
x = dataset[['cgpa']] #Cgpa Column
y = dataset[['package']] #Package Column
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=50)

# %%
# Initiating Model 
model = LinearRegression()

# %%
# Fitting the model to train 
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
# Evaluating 
# 1. Slope
print(f"Slope of Model: {model.coef_[0]}")
# Slope to check increment change in the pridiction against each unit
# ---------------------------------------------------------------------------------------------------------------------------
# Intercept
print(f"Intercpt:{model.intercept_}")
# ---------------------------------------------------------------------------------------------------------------------------
print(f"Mean Squared Error:{mean_squared_error(y_test, y_pred)}")
# ---------------------------------------------------------------------------------------------------------------------------
print(f"R^2 Error:{r2_score(y_test,y_pred)}") # Best Model (.75 to 0.90)
# Out:
# Slope of Model: [0.47204527]
# Intercpt:[-0.43458783]
# Mean Squared Error:0.08447403358902375
# R^2 Error:0.8071016770436981

# %%
# Visualize the regression line
plt.scatter(x,y,color='blue', label="Actual Points")
plt.plot(x, model.predict(x), color='black', label='Regression Line')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Simple Linear Regression")
plt.legend()
plt.show()

# %%
# Take input from user
cgpa_input = float(input("Enter your CGPA: "))

# Predict using the trained model
out = model.predict([[cgpa_input]])

# Print result
print(f"Your Predicted Package is: {out[0][0]} LPA")
# Out:
# Enter your CGPA:  6.73
# Your Predicted Package is: 2.742276822478226 LPA
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
